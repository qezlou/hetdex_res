# %% [markdown]
# ## Reconstruct the Cov:

# %%
import importlib
from het_cov import plot
importlib.reload(plot)

plot_pca = plot.PCA(data_file='pca.h5')
plot_pca.variance_vs_components()
plot_pca.individual_eigenspectrum()
# Out:
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.
# plot.PCA | 09/17/2025 09:43:46 PM | INFO  |  Loaded PCA results for 2774 shots.

# %% [markdown]
# ## Orig vs recon:

# %%
import importlib
from het_cov import plot
importlib.reload(plot)
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display


data_dir = '/home/jovyan/work/hetdex/data'

plot_pca = plot.PCA(data_dir=data_dir)
fig = plot_pca.orig_vs_recon(shotid=plot_pca.shotids[-1], n_components=100)
display(fig)
# Out:
# plot.PCA | 09/17/2025 09:41:46 PM | INFO  |  Loaded PCA results for 2914 shots.
# Fibers | 09/17/2025 09:41:49 PM | INFO  |  we have 6771 shotids in total
# Fibers | 09/17/2025 09:41:49 PM | INFO  |  Masking options: {'bad_fibers': True, 'bad_pixels': True, 'strong_continuum': True}
# Fibers | 09/17/2025 09:41:49 PM | INFO  |  Covariance options: {'per': 'shot', 'method': 'pca', 'l': 2914}
# Fibers | 09/17/2025 09:42:20 PM | INFO  |  Total fibers: 90048
# Fibers | 09/17/2025 09:42:22 PM | INFO  |  Good fibers: 84810, Fraction of good pixels 0.9685947329916201
# Fibers | 09/17/2025 09:42:28 PM | INFO  |   Remaining fraction after removing continuum sources 0.7567032189600283

# %% [markdown]
# ## Removing top variable pixels:

# %%
import importlib
from het_cov import plot
importlib.reload(plot)

plot_pca = plot.PCA(data_file='pca_rm_top.h5')
plot_pca.variance_vs_components()
plot_pca.individual_eigenspectrum()
# Out:
# plot.PCA | 09/17/2025 09:43:01 PM | INFO  |  Loaded PCA results for 141 shots.
# plot.PCA | 09/17/2025 09:43:01 PM | INFO  |  Loaded PCA results for 141 shots.
# plot.PCA | 09/17/2025 09:43:01 PM | INFO  |  Loaded PCA results for 141 shots.
# plot.PCA | 09/17/2025 09:43:01 PM | INFO  |  Loaded PCA results for 141 shots.
# plot.PCA | 09/17/2025 09:43:01 PM | INFO  |  Loaded PCA results for 141 shots.
# plot.PCA | 09/17/2025 09:43:01 PM | INFO  |  Loaded PCA results for 141 shots.
