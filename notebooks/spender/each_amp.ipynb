# %% [markdown]
# # Eech amp
#
# Trained on ~50 consecutive date-shots on LL amp

# %%
import numpy as np

# %%
import plot
import os.path as op
data_dir = '/home/qezlou/projects/lae_detection/data/'

model_path = op.join(data_dir, 'models', 'amp_fibs_LL_c149_latents_5_train_val_shuffle.pt')
spec_file = 'amp_fibs_LL_c149.h5'
spender_plot = plot.HetSpenderPlot(data_dir=data_dir, spec_file=spec_file, model_path=model_path)
# Out:
# /home/qezlou/projects/lae_detection/hetdex_res/notebooks/spender/plot.py:26: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   if which is not 'both':
# Number of files found: 1
# done loading 91291 spectra

# %%
np.array(spender_plot.losses)
# Out:
# array([[0.40807511, 0.38051785],
#        [0.39970814, 0.38027883],
#        [0.39542028, 0.38050825],
#        [0.389693  , 0.38087097],
#        [0.38548612, 0.38130632],
#        [0.38348426, 0.38149835],
#        [0.38269979, 0.38094039],
#        [0.38553071, 0.38192283],
#        [0.38297234, 0.38142065],
#        [0.38257331, 0.38149416],
#        [0.38409514, 0.3805194 ],
#        [0.39225299, 0.38154501],
#        [0.38332728, 0.38224246],
#        [0.38325995, 0.38176287],
#        [0.38410911, 0.38254757],
#        [0.38412587, 0.3809373 ],
#        [0.38679472, 0.38329295],
#        [0.38382343, 0.38075744],
#        [0.38705069, 0.38299921],
#        [0.38466015, 0.38114785],
#        [0.38562104, 0.38064995],
#        [0.38984607, 0.38172596],
#        [0.38429339, 0.38164047],
#        [0.38857821, 0.38986164],
#        [0.38553376, 0.38167928],
#        [0.38881613, 0.38378482],
#        [0.38395459, 0.38340901],
#        [0.38416155, 0.3801223 ],
# ...

# %% [markdown]
# ## randomly smapled from all files:
